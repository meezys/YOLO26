# %%
from ultralytics import YOLO
import torch
import os

# %%
# Quick check to see if dataset is in the same directory
print(f"Dataset exists: {os.path.exists('2025_cone_dataset/train/images')}")
# Out:
# Dataset exists: False

# %%
'''
Training the teacher model
Note that Epochs = 3000 is a rough estimate for grokking to occur
'''
# Import model from 
model = YOLO("yolo26x.pt")

# Training parameters
results = model.train(
    data="2025_cone_dataset.yaml",
    epochs=3000,          # No. of epochs 
    imgsz=1024,           # This is not the final model to be deployed and hence require the highest resolution for generalisation
    batch=-1,             # '-1' auto-adjusts batch size to fill your GPU VRAM
    patience=0,           # We do not stop until the model "comes out" of this plateau stage
    weight_decay=0.1,     # Large weight decay for better generalisation performance
    dropout = 0.2,        # Large dropout for better generalisation performance
    optimizer="MuSGD",    # Best for large models
    lr0=0.01,             # Standard starting learning rate
    cos_lr=True,          # Uses a Cosine Annealing schedule (essential for grokking)
    close_mosaic=20,      # Turn off mosaic augmentation for the last 20 epochs to refine
    overlap_mask=True,    # Helps if cones are partially covering each other
    augment=True,         # Use heavy data augmentation (flips, mosaics, etc.)
    val=True,             # Perform validation at each step
    save_period = 100     # Save weights every 100 epochs
    )

model.save("Yolo26x_Teacher.pt")

print("Model saved and ready for distillation!")

current_dir = os.path.dirname(os.path.abspath(__file__))

if results is not None and hasattr(results, 'save_dir'):
        best_weights = os.path.join(results.save_dir, 'weights', 'best.pt')
else:
    best_weights = os.path.join(current_dir, 'runs', 'Cone_Teacher', 'grokking_run', 'weights', 'best.pt')
    
final_model = YOLO(best_weights)

# Run evaluation on the TEST split
metrics = final_model.val(split='test') 

print(f"Final Test mAP50: {metrics.box.map50}")
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.2 torch-2.5.1 CPU (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=20, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=2025_cone_dataset.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.2, dynamic=False, embed=None, epochs=3000, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26x.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=MuSGD, overlap_mask=True, patience=0, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/perryhui/Desktop/2025_cone_dataset/runs/detect/train, save_frames=False, save_json=False, save_period=100, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.1, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5, 3, True]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   4436736  ultralytics.nn.modules.block.C3k2            [1536, 768, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   6265392  ultralytics.nn.modules.head.Detect           [4, 1, True, [384, 768, 768]]
# YOLO26x summary: 392 layers, 58,817,808 parameters, 58,817,808 gradients
#
# Transferred 1080/1092 items from pretrained weights
# train: Fast image access ✅ (ping: 0.7±0.4 ms, read: 2948.0±1760.3 MB/s, size: 2245.4 KB)
# train: Scanning /Users/perryhui/Desktop/2025_cone_dataset/train/labels... 11248 images, 267 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 11248/11248 350.6it/s 32.1s.1s
# train: New cache created: /Users/perryhui/Desktop/2025_cone_dataset/train/labels.cache
# AutoBatch: Computing optimal batch size for imgsz=1024 at 60.0% CUDA memory utilization.
# WARNING ⚠️ AutoBatch: intended for CUDA devices, using default batch-size 16
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3717.0±4208.7 MB/s, size: 1814.9 KB)
# train: Scanning /Users/perryhui/Desktop/2025_cone_dataset/train/labels.cache... 11248 images, 267 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 11248/11248 2.9Git/s 0.0s
# val: Fast image access ✅ (ping: 0.2±0.1 ms, read: 2593.6±1564.4 MB/s, size: 2159.4 KB)
# val: Scanning /Users/perryhui/Desktop/2025_cone_dataset/val/labels... 3214 images, 75 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3214/3214 357.1it/s 9.0s.3sss
# val: New cache created: /Users/perryhui/Desktop/2025_cone_dataset/val/labels.cache
# Plotting labels to /Users/perryhui/Desktop/2025_cone_dataset/runs/detect/train/labels.jpg...
# optimizer: MuSGD(lr=0.01, momentum=0.937) with parameter groups 178 weight(decay=0.0), 190 weight(decay=0.1), 190 bias(decay=0.0)
# Image sizes 1024 train, 1024 val
# Using 0 dataloader workers
# Logging results to /Users/perryhui/Desktop/2025_cone_dataset/runs/detect/train
# Starting training for 3000 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# : 0% ──────────── 0/703  32.1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 11
#       9 dataset_root = os.path.abspath("datasets/2025_cone_dataset")
#      10 # Training parameters
# ---> 11 results = model.train(
#      12     data="2025_cone_dataset.yaml",
#      13     epochs=3000,          # No. of epochs
#      14     imgsz=1024,           # This is not the final model to be deployed and hence require the highest resolution for generalisation
#      15     batch=-1,             # '-1' auto-adjusts batch size to fill your GPU VRAM
#      16     patience=0,           # We do not stop until the model "comes out" of this plateau stage
#      17     weight_decay=0.1,     # Large weight decay for better generalisation performance
#      18     dropout = 0.2,        # Large dropout for better generalisation performance
#      19     optimizer="MuSGD",    # Best for large models
#      20     lr0=0.01,             # Standard starting learning rate
#      21     cos_lr=True,          # Uses a Cosine Annealing schedule (essential for grokking)
#      22     close_mosaic=20,      # Turn off mosaic augmentation for the last 20 epochs to refine
#      23     overlap_mask=True,    # Helps if cones are partially covering each other
#      24     augment=True,         # Use heavy data augmentation (flips, mosaics, etc.)
#      25     val=True,              # Perform validation at each step
#      26     save_period = 100     # Save weights every 100 epochs
#      27     )
#      29 model.save("Yolo26x_Teacher.pt")
#      31 print("Model saved and ready for distillation!")
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/model.py:774, in Model.train(self, trainer, **kwargs)
#     771     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     772     self.model = self.trainer.model
# --> 774 self.trainer.train()
#     775 # Update model and cfg after training
#     776 if RANK in {-1, 0}:
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/trainer.py:244, in BaseTrainer.train(self)
#     241         ddp_cleanup(self, str(file))
#     243 else:
# --> 244     self._do_train()
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/trainer.py:433, in BaseTrainer._do_train(self)
#     431     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     432 else:
# --> 433     loss, self.loss_items = self.model(batch)
#     434 self.loss = loss.sum()
#     435 if RANK != -1:
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/nn/tasks.py:141, in BaseModel.forward(self, x, *args, **kwargs)
#     128 """Perform forward pass of the model for either training or inference.
#     129
#     130 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)
#     138     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     139 """
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 141     return self.loss(x, *args, **kwargs)
#     142 return self.predict(x, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/nn/tasks.py:332, in BaseModel.loss(self, batch, preds)
#     329     self.criterion = self.init_criterion()
#     331 if preds is None:
# --> 332     preds = self.forward(batch["img"])
#     333 return self.criterion(preds, batch)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/nn/tasks.py:142, in BaseModel.forward(self, x, *args, **kwargs)
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
#     141     return self.loss(x, *args, **kwargs)
# --> 142 return self.predict(x, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/nn/tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     157 if augment:
#     158     return self._predict_augment(x)
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/nn/tasks.py:181, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     179 if profile:
#     180     self._profile_one_layer(m, x, dt)
# --> 181 x = m(x)  # run
#     182 y.append(x if m.i in self.save else None)  # save output
#     183 if visualize:
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:312, in C2f.forward(self, x)
#     310 y = list(self.cv1(x).chunk(2, 1))
#     311 y.extend(m(y[-1]) for m in self.m)
# --> 312 return self.cv2(torch.cat(y, 1))
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/nn/modules/conv.py:78, in Conv.forward(self, x)
#      69 def forward(self, x):
#      70     """Apply convolution, batch normalization and activation to input tensor.
#      71
#      72     Args:
#    (...)
#      76         (torch.Tensor): Output tensor.
#      77     """
# ---> 78     return self.act(self.bn(self.conv(x)))
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %%
'''
Knowledge Distillation
Training a smaller YOLO26n with knowldge from the teacher model trained above
'''

teacher = YOLO("Yolo26x_Teacher.pt")

student = YOLO("yolo26n.pt")

results = model.train(
    data="2025_cone_dataset.yaml",
    teacher=teacher.model,         # Pass the underlying PyTorch model
    imgsz= 640,                     # Student resolution 
    teacher_imgsz=1024,            # Teacher's resolution expertise
    epochs=500,                    # Student needs fewer epochs with a guide
    batch=128,                     # High batch size for stable gradients
    optimizer="AdamW",             # Better for small models than MuSGD
    distill_loss="cwd",            # Channel-wise distillation for better boundaries
)

student.save("Yolo26n_Final.pt")
